# %% [markdown]
# # Pre-Industrial Control Data analysis

# %%
# !mamba install --file /home/jovyan/pangeo/code/requirements.txt

# %%
from matplotlib import pyplot as plt
import xarray as xr
import numpy as np
import dask
from dask.diagnostics import progress
from tqdm.autonotebook import tqdm 
import intake
import fsspec
import seaborn as sns
import esmvalcore.preprocessor as ecpr
import pymannkendall as mkt

# %matplotlib inline
# Out:
# /tmp/ipykernel_920/4170856221.py:6: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
col = intake.open_esm_datastore("https://storage.googleapis.com/cmip6/pangeo-cmip6.json")
col

# there is currently a significant amount of data for these runs
expts_full = ['historical', 'ssp126', 'ssp245','ssp370', 'ssp585', 'piControl']

query = dict(
    experiment_id=expts_full,
    table_id='Amon',                           
    variable_id=['tas', 'pr', 'ua', 'va'],
    member_id = 'r1i1p1f1',                     
)

col_subset = col.search(require_all_on=["source_id"], **query)
col_subset_var = [col_subset.search(variable_id=var_name) for var_name in query['variable_id']]
col_subset.df.groupby("source_id")[
    ["experiment_id", "variable_id", "table_id"]
].nunique()
#col_subset
# Out:
#                   experiment_id  variable_id  table_id
# source_id
# ACCESS-CM2                    6            4         1
# AWI-CM-1-1-MR                 6            4         1
# BCC-CSM2-MR                   6            4         1
# CAMS-CSM1-0                   6            4         1
# CESM2-WACCM                   6            4         1
# CMCC-CM2-SR5                  6            4         1
# CMCC-ESM2                     6            4         1
# CanESM5                       6            4         1
# EC-Earth3                     6            4         1
# EC-Earth3-Veg                 6            4         1
# EC-Earth3-Veg-LR              6            4         1
# FGOALS-f3-L                   6            4         1
# FGOALS-g3                     6            4         1
# GFDL-ESM4                     6            4         1
# IITM-ESM                      6            4         1
# INM-CM4-8                     6            4         1
# INM-CM5-0                     6            4         1
# IPSL-CM6A-LR                  6            4         1
# KACE-1-0-G                    6            4         1
# MIROC6                        6            4         1
# MPI-ESM1-2-HR                 6            4         1
# MPI-ESM1-2-LR                 6            4         1
# MRI-ESM2-0                    6            4         1
# NorESM2-MM                    6            4         1
# TaiESM1                       6            4         1

# %%
def drop_all_bounds(ds):
    drop_vars = [vname for vname in ds.coords
                 if (('_bounds') in vname ) or ('_bnds') in vname]
    return ds.drop(drop_vars)

def open_dset(df):
    #assert len(df) == 1
    ds = xr.open_zarr(fsspec.get_mapper(df.zstore.values[0]), consolidated=True, decode_times=True, use_cftime=True)
    return drop_all_bounds(ds)

def open_delayed(df):
    return dask.delayed(open_dset)(df)

from collections import defaultdict
dsets = []
for col_subset in col_subset_var :
    dset = defaultdict(dict)

    for group, df in col_subset.df.groupby(by=['source_id', 'experiment_id']):
        dset[group[0]][group[1]] = open_delayed(df)
    dsets.append(dset)

# %%
with progress.Progressbar:
    dsets_ = [dask.compute(dict(dset))[0]for dset in dsets]

# %%
dset_dict = col_subset_var[0].to_dataset_dict(
    zarr_kwargs={"consolidated": True, "decode_times": True, "use_cftime": True}
)
ss = [key for key in dset_dict.keys() if 'piControl' in key]
ss[9]
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='150' class='' max='150' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [150/150 00:05<00:00]
#     </div>
# 'CMIP.CAS.FGOALS-f3-L.piControl.Amon.gr'

# %%
import pandas as pd
df = pd.DataFrame(columns=['Model name', 'lat_res', 'lon_res', 'shape (lat x lon)'])
for idx,s in enumerate(ss):
    ds = dset_dict[s]
    lat_num = ds.lat.shape
    lon_num = ds.lon.shape
    df.loc[len(df.index)] = [s, round(180.0/lat_num[0],3) , round(360.0/lon_num[0],3) ,(ds.tas.squeeze().shape[1], ds.tas.squeeze().shape[2])]
df
# Out:
#                                            Model name  lat_res  lon_res  \
# 0               CMIP.INM.INM-CM5-0.piControl.Amon.gr1    1.500    2.000
# 1            CMIP.IPSL.IPSL-CM6A-LR.piControl.Amon.gr    1.259    2.500
# 2   CMIP.EC-Earth-Consortium.EC-Earth3-Veg.piContr...    0.703    0.703
# 3              CMIP.BCC.BCC-CSM2-MR.piControl.Amon.gn    1.125    1.125
# 4               CMIP.MRI.MRI-ESM2-0.piControl.Amon.gn    1.125    1.125
# 5           CMIP.CCCR-IITM.IITM-ESM.piControl.Amon.gn    1.915    1.875
# 6               CMIP.CMCC.CMCC-ESM2.piControl.Amon.gn    0.938    1.250
# 7            CMIP.AWI.AWI-CM-1-1-MR.piControl.Amon.gn    0.938    0.938
# 8         CMIP.NOAA-GFDL.GFDL-ESM4.piControl.Amon.gr1    1.000    1.250
# 9              CMIP.CAS.FGOALS-f3-L.piControl.Amon.gr    1.000    1.250
# 10           CMIP.CMCC.CMCC-CM2-SR5.piControl.Amon.gn    0.938    1.250
# 11  CMIP.EC-Earth-Consortium.EC-Earth3-Veg-LR.piCo...    1.125    1.125
# 12            CMIP.CAMS.CAMS-CSM1-0.piControl.Amon.gn    1.125    1.125
# 13              CMIP.INM.INM-CM4-8.piControl.Amon.gr1    1.500    2.000
# 14              CMIP.NCC.NorESM2-MM.piControl.Amon.gn    0.938    1.250
# 15               CMIP.CCCma.CanESM5.piControl.Amon.gn    2.812    2.812
# 16         CMIP.NIMS-KMA.KACE-1-0-G.piControl.Amon.gr    1.250    1.875
# 17         CMIP.MPI-M.MPI-ESM1-2-LR.piControl.Amon.gn    1.875    1.875
# 18         CMIP.MPI-M.MPI-ESM1-2-HR.piControl.Amon.gn    0.938    0.938
# 19            CMIP.NCAR.CESM2-WACCM.piControl.Amon.gn    0.938    1.250
# 20                CMIP.MIROC.MIROC6.piControl.Amon.gn    1.406    1.406
# 21  CMIP.EC-Earth-Consortium.EC-Earth3.piControl.A...    0.703    0.703
# 22               CMIP.CAS.FGOALS-g3.piControl.Amon.gn    2.250    2.000
# 23     CMIP.CSIRO-ARCCSS.ACCESS-CM2.piControl.Amon.gn    1.250    1.875
# 24             CMIP.AS-RCEC.TaiESM1.piControl.Amon.gn    0.938    1.250
#
#    shape (lat x lon)
# 0         (120, 180)
# 1         (143, 144)
# 2         (256, 512)
# 3         (160, 320)
# 4         (160, 320)
# 5          (94, 192)
# 6         (192, 288)
# 7         (192, 384)
# 8         (180, 288)
# 9         (180, 288)
# 10        (192, 288)
# 11        (160, 320)
# 12        (160, 320)
# 13        (120, 180)
# 14        (192, 288)
# 15         (64, 128)
# 16        (144, 192)
# 17         (96, 192)
# 18        (192, 384)
# 19        (192, 288)
# 20        (128, 256)
# 21        (256, 512)
# 22         (80, 180)
# 23        (144, 192)
# 24        (192, 288)
